# %% [markdown]
# # MovieLens Data Analysis

# %%
import pandas as pd

# %%
# Loading the files
movies = pd.read_csv('/kaggle/input/movielens/data/data/ml-32m/movies.csv')
glmer = pd.read_csv('/kaggle/input/movielens/data/data/tag-genome-2021/scores/glmer.csv')
ratings = pd.read_csv('/kaggle/input/movielens/data/data/ml-32m/ratings.csv')
links = pd.read_csv('/kaggle/input/movielens/data/data/ml-32m/links.csv')
tags = pd.read_csv('/kaggle/input/movielens/data/data/ml-32m/tags.csv')
tags_json = pd.read_json('/kaggle/input/movielens/data/data/tag-genome-2021/raw/tags.json', lines=True)

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
glmer.head()
# Out:
#         tag  item_id     score
# 0  airplane        2  0.042391
# 1  airplane        3  0.050673
# 2  airplane        4  0.033161
# 3  airplane        5  0.047030
# 4  airplane        6  0.051117

# %%
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1       17     4.0  944249077
# 1       1       25     1.0  944250228
# 2       1       29     2.0  943230976
# 3       1       30     5.0  944249077
# 4       1       32     5.0  943228858

# %%
tags.head()
# Out:
#    userId  movieId          tag   timestamp
# 0      22    26479  Kevin Kline  1583038886
# 1      22    79592     misogyny  1581476297
# 2      22   247150   acrophobia  1622483469
# 3      34     2174        music  1249808064
# 4      34     2174        weird  1249808102

# %%
tags['tag'] = tags['tag'].str.lower()

# %%
populer_tags = tags['tag'].value_counts()
populer_tags.head(50)
# Out:
# tag
# sci-fi                   11437
# atmospheric              10088
# action                    9337
# comedy                    8784
# funny                     8088
# surreal                   7480
# visually appealing        7253
# based on a book           6728
# twist ending              6600
# dark comedy               6153
# thought-provoking         6003
# romance                   5961
# dystopia                  5713
# violence                  5454
# cinematography            5429
# murder                    5238
# social commentary         5200
# fantasy                   5148
# quirky                    4954
# stylized                  4948
# psychology                4847
# dark                      4825
# adventure                 4813
# classic                   4740
# time travel               4738
# coming of age             4493
# revenge                   4419
# drama                     4407
# friendship                4391
# suspense                  4381
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

plt.figure(figsize=(10,8))

sns.countplot(x='rating', data=ratings)

plt.show()
